# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot([2,4,6,4,8])
plt.ylabel('numbers')
plt.xlabel('Indices')
plt.title('MyPlot')
plt.show()

# %%
pms=[75,80,85,90,95,100,105,110,115]
a=[-2,-2,-2,-2,-2,3,8,13,18]
b=[4,4,4,4,-1,-6,-11,-16,-21]
c=[-8,-3,2,2,2,2,2,2,2]
d=[14,9,4,-1,-6,-11,-11,-11,-11]
abcd=[8,8,8,3,-7,-12,-12,-12,-12]

# %%
plt.plot([1,2,3,4],[1,2,3,4],'bo')
plt.ylabel('numbers')
plt.xlabel('Indices')
plt.title('MyPlot')
plt.grid()
plt.show()

# %%
t=np.arange(0.,5.,.2)

plt.plot(t,t**2,'b--',label='^2')
plt.plot(t,t**2.2,'rs',label='^2.2')
plt.plot(t,t**2.5,'g^',label='^2.5')
plt.grid()
plt.xlabel('mahesh')
plt.ylabel('g')
plt.legend()
plt.show()

# %%
plt.figure(1)
pms=[75,80,85,90,95,100,105,110,115]
a=[-2,-2,-2,-2,-2,3,8,13,18]
b=[4,4,4,4,-1,-6,-11,-16,-21]
c=[-8,-3,2,2,2,2,2,2,2]
d=[14,9,4,-1,-6,-11,-11,-11,-11]
abcd=[8,8,8,3,-7,-12,-12,-12,-12]

plt.plot(pms,a,'b--',label='long call')
plt.plot(pms,b,'r--',label='short call')
plt.plot(pms,c,'g--',label='long put')
plt.plot(pms,d,'y--',label='short put')
plt.plot(pms,abcd,label='net', linewidth=5)
plt.legend()

plt.grid()

# %%
def f(t):
    return np.exp(-t)*np.cos(2*np.pi*t)
t1=np.arange(0.0,5.0,0.02)
t2=np.arange(0.0,5.0,0.02)
plt.
# Out:
#   File "<ipython-input-7-86a4c4f128e9>", line 5
#     plt.
#         ^
# SyntaxError: invalid syntax

# %%
plt.figure(1)

pms=[75,80,85,90,95,100,105,110,115]
a=[-2,-2,-2,-2,-2,3,8,13,18]
b=[4,4,4,4,-1,-6,-11,-16,-21]
c=[-8,-3,2,2,2,2,2,2,2]
d=[14,9,4,-1,-6,-11,-11,-11,-11]
abcd=[8,8,8,3,-7,-12,-12,-12,-12]

plt.subplot(511)
plt.plot(pms,a,'b--',label='long call')
plt.grid()
plt.legend()
plt.subplot(512)
plt.plot(pms,b,'r--',label='short call')
plt.grid()
plt.legend()
plt.subplot(513)
plt.plot(pms,c,'g--',label='long put')
plt.grid()
plt.legend()
plt.subplot(514)
plt.plot(pms,d,'y--',label='short put')
plt.grid()
plt.legend()
plt.subplot(515)
plt.plot(pms,abcd,linewidth=5)
plt.grid()
plt.legend()
plt.legend()
plt.show()

# %%
def f(t):
    return np.exp(-t)*np.cos(2*np.pi*t)
t1= np.arange(0.0,5.0,0.1)
t2= np.arange(0.0,5.0,0.02)
plt.figure(1,figsize=(8,10))
plt.subplot(421)
plt.grid()
plt.plot(t1,f(t1),'y-')
plt.subplot(423)
plt.grid()
plt.plot(t1,f(t1),'m-')
plt.subplot(424)
plt.grid()
plt.plot(t1,f(t1),'g-')
plt.subplot(422)
plt.plot(t2,np.cos(2*np.pi*t2),'r--')
plt.show()

# %%
plt.figure(1)

plt.subplot(211)
plt.plot([1,2,3])
plt.subplot(212)
plt.plot([4,5,6])

plt.figure(2)

plt.plot([4,5,6],'r--')

plt.figure(1)
plt.subplot(211)
plt.title('easy as 1,2,3')
plt.show()

# %%
import numpy as np
x=np.random.randn(100)
plt.hist(x)
#plt.plot(x)

plt.show()

# %%
f=[40,20,30,50]
plt.pie(f,labels=['k','l','o','j'],shadow=1)
plt.show()

# %%
import numpy as np
x=np.random.randn(100)
plt.figure(2)
plt.subplot(221)
plt.hist(x)
f=[40,20,30,50]
plt.subplot(222)
plt.pie(f,labels=['k','l','o','j'],shadow=1)
a=np.arange(1,11,1)
b=np.arange(1,21,2)
plt.subplot(223)
plt.bar(a,b)
plt.subplot(224)
t=[1,2,3,4,5]
y=[3,2,4,5,2]
plt.plot(t,y)
plt.show()

# %%
v='string'
v.upper()
# Out:
# 'STRING'

# %%
from datetime import date
date(2015,1,1)
# Out:
# datetime.date(2015, 1, 1)

# %%
import nsepy as nse

# %%
tick=str(raw_input('name of stock :')).upper()
STD=date(2015,1,1)
END=date(2019,5,15)
d=nse.get_history(str(tick),STD,END)
dt=pd.DataFrame(d)
# Out:
# name of stock :hdfc

# %%
dt
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2015-01-01   HDFC     EQ     1135.90  1130.00  1131.15  1120.10  1125.90
# 2015-01-02   HDFC     EQ     1124.00  1127.30  1176.95  1125.35  1171.05
# 2015-01-05   HDFC     EQ     1171.90  1168.80  1175.00  1150.40  1154.95
# 2015-01-06   HDFC     EQ     1156.40  1148.60  1148.60  1096.10  1098.00
# 2015-01-07   HDFC     EQ     1101.95  1097.50  1114.15  1095.00  1097.65
# 2015-01-08   HDFC     EQ     1099.25  1114.00  1128.50  1110.00  1122.15
# 2015-01-09   HDFC     EQ     1123.35  1127.00  1135.95  1103.40  1110.00
# 2015-01-12   HDFC     EQ     1113.30  1114.35  1135.00  1098.40  1129.15
# 2015-01-13   HDFC     EQ     1128.55  1134.40  1137.30  1113.60  1123.10
# 2015-01-14   HDFC     EQ     1122.20  1128.70  1136.85  1112.60  1120.90
# 2015-01-15   HDFC     EQ     1120.30  1145.05  1210.90  1144.70  1194.00
# 2015-01-16   HDFC     EQ     1202.55  1207.50  1209.00  1191.00  1198.00
# ...

# %%
tick=str(raw_input('name of stock :')).upper()
STD=date(2015,1,1)
END=date(2019,5,15)
d=nse.get_history(str(tick),STD,END)
dt=pd.DataFrame(d)
dt
# Out:
# name of stock :itc
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01    ITC     EQ      368.70  367.60  368.90  366.00  367.15  367.15
# 2015-01-02    ITC     EQ      367.15  367.25  370.15  367.25  368.00  368.30
# 2015-01-05    ITC     EQ      368.30  368.70  371.80  367.55  369.50  369.75
# 2015-01-06    ITC     EQ      369.75  368.65  369.40  359.00  360.00  360.25
# 2015-01-07    ITC     EQ      360.25  357.00  364.00  353.00  353.90  353.55
# 2015-01-08    ITC     EQ      353.55  355.45  363.35  355.45  361.80  362.40
# 2015-01-09    ITC     EQ      362.40  363.10  365.85  353.10  358.85  356.90
# 2015-01-12    ITC     EQ      356.90  357.45  361.35  356.10  357.90  357.85
# 2015-01-13    ITC     EQ      357.85  358.40  361.70  357.30  361.05  360.10
# 2015-01-14    ITC     EQ      360.10  359.70  359.70  346.10  348.45  347.80
# 2015-01-15    ITC     EQ      347.80  353.10  359.90  350.90  356.35  357.90
# ...

# %%
tick=str(raw_input('name of stock :')).upper()
STD=date(2015,1,1)
END=date(2019,5,15)
d=nse.get_history(str(tick),STD,END)
dt=pd.DataFrame(d)
dt
# Out:
# name of stock :cleducate
#                Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2017-04-18  CLEDUCATE     EQ      425.70  418.10  474.95  418.10  430.55
# 2017-04-19  CLEDUCATE     EQ      432.50  432.95  450.50  432.95  440.00
# 2017-04-20  CLEDUCATE     EQ      439.95  441.00  453.00  440.00  441.75
# 2017-04-21  CLEDUCATE     EQ      441.65  444.85  446.95  431.00  434.90
# 2017-04-24  CLEDUCATE     EQ      434.75  443.90  443.90  428.45  438.95
# 2017-04-25  CLEDUCATE     EQ      438.10  432.00  449.95  432.00  437.70
# 2017-04-26  CLEDUCATE     EQ      436.75  431.55  442.90  431.55  436.00
# 2017-04-27  CLEDUCATE     EQ      437.20  431.50  445.00  431.50  437.00
# 2017-04-28  CLEDUCATE     EQ      438.00  432.50  469.00  432.50  465.00
# 2017-05-02  CLEDUCATE     EQ      456.90  469.00  469.00  446.05  455.00
# 2017-05-03  CLEDUCATE     EQ      451.80  453.30  454.45  441.55  442.00
# ...
