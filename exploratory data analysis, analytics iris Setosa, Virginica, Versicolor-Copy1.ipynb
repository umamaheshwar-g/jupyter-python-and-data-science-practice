# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# variables
# vectors
# features

# %%
iris=pd.read_csv('iris.csv')
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# 13            4.3          3.0           1.1          0.1     Setosa
# 14            5.8          4.0           1.2          0.2     Setosa
# 15            5.7          4.4           1.5          0.4     Setosa
# 16            5.4          3.9           1.3          0.4     Setosa
# 17            5.1          3.5           1.4          0.3     Setosa
# 18            5.7          3.8           1.7          0.3     Setosa
# 19            5.1          3.8           1.5          0.3     Setosa
# 20            5.4          3.4           1.7          0.2     Setosa
# 21            5.1          3.7           1.5          0.4     Setosa
# 22            4.6          3.6           1.0          0.2     Setosa
# 23            5.1          3.3           1.7          0.5     Setosa
# 24            4.8          3.4           1.9          0.2     Setosa
# 25            5.0          3.0           1.6          0.2     Setosa
# 26            5.0          3.4           1.6          0.4     Setosa
# 27            5.2          3.5           1.5          0.2     Setosa
# 28            5.2          3.4           1.4          0.2     Setosa
# 29            4.7          3.2           1.6          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  Virginica
# 121           5.6          2.8           4.9          2.0  Virginica
# 122           7.7          2.8           6.7          2.0  Virginica
# 123           6.3          2.7           4.9          1.8  Virginica
# 124           6.7          3.3           5.7          2.1  Virginica
# 125           7.2          3.2           6.0          1.8  Virginica
# 126           6.2          2.8           4.8          1.8  Virginica
# 127           6.1          3.0           4.9          1.8  Virginica
# 128           6.4          2.8           5.6          2.1  Virginica
# 129           7.2          3.0           5.8          1.6  Virginica
# 130           7.4          2.8           6.1          1.9  Virginica
# 131           7.9          3.8           6.4          2.0  Virginica
# 132           6.4          2.8           5.6          2.2  Virginica
# 133           6.3          2.8           5.1          1.5  Virginica
# 134           6.1          2.6           5.6          1.4  Virginica
# 135           7.7          3.0           6.1          2.3  Virginica
# 136           6.3          3.4           5.6          2.4  Virginica
# 137           6.4          3.1           5.5          1.8  Virginica
# 138           6.0          3.0           4.8          1.8  Virginica
# 139           6.9          3.1           5.4          2.1  Virginica
# 140           6.7          3.1           5.6          2.4  Virginica
# 141           6.9          3.1           5.1          2.3  Virginica
# 142           5.8          2.7           5.1          1.9  Virginica
# 143           6.8          3.2           5.9          2.3  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris['variety'].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
iris.columns
# Out:
# Index([u'sepal.length', u'sepal.width', u'petal.length', u'petal.width',
#        u'variety'],
#       dtype='object')

# %%
n=len(iris['petal.width'])
a=np.zeros(n)

# %%
plt.plot(iris['petal.width'],a)

# %%
plt.scatter(iris['petal.length'],iris['petal.width'])

# %%
a=iris['petal.width'][iris['variety']=='Setosa']
# Out:
# 0     0.2
# 1     0.2
# 2     0.2
# 3     0.2
# 4     0.2
# 5     0.4
# 6     0.3
# 7     0.2
# 8     0.2
# 9     0.1
# 10    0.2
# 11    0.2
# 12    0.1
# 13    0.1
# 14    0.2
# 15    0.4
# 16    0.4
# 17    0.3
# 18    0.3
# 19    0.3
# 20    0.2
# 21    0.4
# 22    0.2
# 23    0.5
# 24    0.2
# 25    0.2
# 26    0.4
# 27    0.2
# 28    0.2
# 29    0.2
# 30    0.2
# 31    0.4
# 32    0.1
# 33    0.2
# 34    0.2
# 35    0.2
# 36    0.2
# 37    0.1
# 38    0.2
# 39    0.2
# 40    0.3
# 41    0.3
# 42    0.2
# 43    0.6
# 44    0.4
# 45    0.3
# 46    0.2
# 47    0.2
# 48    0.2
# 49    0.2
# Name: petal.width, dtype: float64

# %%
a=iris['petal.width'][iris['variety']=='Setosa']
# Out:
# <bound method Series.count of 0     0.2
# 1     0.2
# 2     0.2
# 3     0.2
# 4     0.2
# 5     0.4
# 6     0.3
# 7     0.2
# 8     0.2
# 9     0.1
# 10    0.2
# 11    0.2
# 12    0.1
# 13    0.1
# 14    0.2
# 15    0.4
# 16    0.4
# 17    0.3
# 18    0.3
# 19    0.3
# 20    0.2
# 21    0.4
# 22    0.2
# 23    0.5
# 24    0.2
# 25    0.2
# 26    0.4
# 27    0.2
# 28    0.2
# 29    0.2
# 30    0.2
# 31    0.4
# 32    0.1
# 33    0.2
# 34    0.2
# 35    0.2
# 36    0.2
# 37    0.1
# 38    0.2
# 39    0.2
# 40    0.3
# 41    0.3
# 42    0.2
# 43    0.6
# 44    0.4
# 45    0.3
# 46    0.2
# 47    0.2
# 48    0.2
# 49    0.2
# Name: petal.width, dtype: float64>

# %%
a=[iris['petal.width'][iris['variety']=='Setosa']]
b=iris['petal.width'][iris['variety']=='Virginica']
c=iris['petal.width'][iris['variety']=='Versicolor']
aa=np.zeros(len(a))
bb=np.zeros(len(b))
cc=np.zeros(len(c))
# Out:
# [0     0.2
#  1     0.2
#  2     0.2
#  3     0.2
#  4     0.2
#  5     0.4
#  6     0.3
#  7     0.2
#  8     0.2
#  9     0.1
#  10    0.2
#  11    0.2
#  12    0.1
#  13    0.1
#  14    0.2
#  15    0.4
#  16    0.4
#  17    0.3
#  18    0.3
#  19    0.3
#  20    0.2
#  21    0.4
#  22    0.2
#  23    0.5
#  24    0.2
#  25    0.2
#  26    0.4
#  27    0.2
#  28    0.2
#  29    0.2
#  30    0.2
#  31    0.4
#  32    0.1
#  33    0.2
#  34    0.2
#  35    0.2
#  36    0.2
#  37    0.1
#  38    0.2
#  39    0.2
#  40    0.3
#  41    0.3
#  42    0.2
#  43    0.6
#  44    0.4
#  45    0.3
#  46    0.2
#  47    0.2
#  48    0.2
#  49    0.2
#  Name: petal.width, dtype: float64]

# %%
plt.scatter(a,aa,c='b',s=40)
plt.scatter(b,bb,c='g', s=40)
plt.scatter(c,cc,c='r',s=40)

# %%
plt.scatter(x=[a,b,c],y=[aa,bb,cc],c=['b','g','y'],s=40)

# %% [markdown]
# import seaborn as sns

# %%
sns.FacetGrid(iris, hue='variety',size=5).map(sns.distplot,'petal.length').add_legend()
sns.FacetGrid(iris, hue='variety',size=5).map(sns.distplot,'petal.width').add_legend()
sns.FacetGrid(iris, hue='variety',size=5).map(sns.distplot,'sepal.length').add_legend()
sns.FacetGrid(iris, hue='variety',size=5).map(sns.distplot,'sepal.width').add_legend()
plt.show()

# %% [markdown]
# histogram
# interval
# frequency

# %%
iris_setosa=iris.loc[iris['variety']=='Setosa']
iris_virginica=iris.loc[iris['variety']=='Virginica']
iris_versicolor=iris.loc[iris['variety']=='Versicolor']

# %%
counts, bin_edges = np.histogram(iris_setosa['petal.length'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
counts, bin_edges = np.histogram(iris_setosa['petal.length'], bins=20, density = True)
#plt.show();

counts, bin_edges = np.histogram(iris_virginica['petal.length'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
counts, bin_edges = np.histogram(iris_virginica['petal.length'], bins=20, density = True)
#plt.show();

counts, bin_edges = np.histogram(iris_versicolor['petal.length'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
counts, bin_edges = np.histogram(iris_versicolor['petal.length'], bins=20, density = True)



plt.show();
# Out:
# [0.02 0.02 0.04 0.14 0.26 0.26 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %%
print("Means:")
print(np.mean(iris_setosa["petal.length"]))
#Mean with an outliner.
print(np.mean(np.append(iris_setosa["petal.length"],50)))

print(np.mean(iris_virginica["petal.length"]))
print(np.mean(iris_versicolor["petal.length"]))

print("\nstd-dev:");
print(np.std(iris_setosa["petal.length"]))
print(np.std(iris_virginica["petal.length"]))
print(np.std(iris_versicolor["petal.length"]))
# Out:
# Means:
# 1.462
# 2.4137254901960787
# 5.552
# 4.26
#
# std-dev:
# 0.171918585383
# 0.546347874527
# 0.465188133985

# %%
print("\nMedians:")
print(np.median(iris_setosa["petal.length"]))

print(np.median(np.append(iris_setosa["petal.length"],50)))
print(np.median(iris_virginica["petal.length"]))
print(np.median(iris_versicolor["petal.length"]))

print("\nQualities:")
print(np.percentile(iris_setosa["petal.length"],np.arange(0,100,25)))
print(np.percentile(iris_virginica["petal.length"],np.arange(0,100,25)))
print(np.percentile(iris_versicolor["petal.length"],np.arange(0,100,25)))

print("\n90th percentiles:")
print(np.percentile(iris_setosa["petal.length"],90))
print(np.percentile(iris_virginica["petal.length"],90))
print(np.percentile(iris_versicolor["petal.length"],90))

from statsmodels import robust
print("\nMedian Absolute Deviation:")
print(robust.mad(iris_setosa["petal.length"]))#median absolute deviation
print(robust.mad(iris_virginica["petal.length"]))
print(robust.mad(iris_versicolor["petal.length"]))
# Out:
# Medians:
# 1.5
# 1.5
# 5.55
# 4.35
#
# Qualities:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# 90th percentiles:
# 1.7
# 6.3100000000000005
# 4.8
#
# Median Absolute Deviation:
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %%
sns.boxplot(x='variety',y='petal.length',data=iris)
plt.show()

# %%
sns.violinplot(x='variety',y='petal.length',data=iris)

plt.show()

# %%
plt.close()
sns.set_style('whitegrid')
sns.pairplot(iris,hue='variety',size=3)
plt.show()

# %%
sns.jointplot(x='petal.length',y='sepal.width',data=iris_setosa,kind='kde')
plt.show()
# Out:
# C:\Users\umama\Anaconda2\lib\site-packages\numpy\ma\core.py:6442: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# C:\Users\umama\Anaconda2\lib\site-packages\numpy\ma\core.py:6442: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
