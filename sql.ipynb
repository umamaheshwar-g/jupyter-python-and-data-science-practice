# %%
import sqlite3
import pandas as pd

# %%
amazon=sqlite3.connect('database.sqlite')

# %%
pd.read_sql_query("""SELECT * FROM Reviews LIMIT 6""",amazon)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
# 5                     0                       0      4  1342051200
#
# ...

# %%
pd.read_sql_query("""SELECT ProductId,UserId FROM Reviews LIMIT 5""",amazon)
# Out:
#     ProductId          UserId
# 0  B001E4KFG0  A3SGXH7AUHU8GW
# 1  B00813GRG4  A1D87F6ZCVE5NK
# 2  B000LQOCH0   ABXLMWJIXXAIN
# 3  B000UA0QIQ  A395BORC6FGVXV
# 4  B006K2ZZ7K  A1UQRSCLF8GW1T

# %%
pd.read_sql_query("""SELECT ProductId,UserId,ProfileName  FROM Reviews LIMIT 20 """,amazon)
# Out:
#      ProductId          UserId                      ProfileName
# 0   B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7   B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8   B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9   B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
# 10  B0001PB9FE  A3HDKO7OW0QNK4                     Canadian Fan
# 11  B0009XLVG0  A2725IB4YY9JEB           A Poeng "SparkyGoHome"
# 12  B0009XLVG0   A327PCT23YH90                               LT
# 13  B001GVISJM  A18ECVX2RJ7HUE                  willie "roadie"
# ...

# %%
pd.read_sql_query("""select ProductId,UserId,ProfileName  FROM Reviews LIMIT 20 OFFSET 15""",amazon)
# Out:
#      ProductId          UserId                   ProfileName
# 0   B001GVISJM  A1CZX3CP8IKQIJ                  Brian A. Lee
# 1   B001GVISJM  A3KLWF6WQ5BNYO                Erica Neathery
# 2   B001GVISJM   AFKW14U97Z6QO                         Becca
# 3   B001GVISJM  A2A9X58G2GTBLP                       Wolfee1
# 4   B001GVISJM  A3IV7CL2C13K2U                          Greg
# 5   B001GVISJM  A1WO0KGLPR5PV6                      mom2emma
# 6   B001GVISJM   AZOF9E17RGZH8                Tammy Anderson
# 7   B001GVISJM   ARYVQL4N737A1                 Charles Brown
# 8   B001GVISJM   AJ613OLZZUG7V                        Mare's
# 9   B001GVISJM  A22P2J09NJ9HKE   S. Cabanaugh "jilly pepper"
# 10  B001GVISJM  A3FONPR03H3PJS  Deborah S. Linzer "Cat Lady"
# 11  B001GVISJM  A3RXAU2N8KV45G                        lady21
# 12  B001GVISJM   AAAS38B98HMIK                  Heather Dube
# 13  B00144C10S  A2F4LZVGFLD1OB                        DaisyH
# ...

# %%
pd.read_sql_query("""SELECT *  FROM Reviews ORDER BY ProductId LIMIT 20 OFFSET 60""",amazon)
# Out:
#         Id   ProductId          UserId  \
# 0   171123  7310172001   AYS3F0L3VFP6G
# 1   171124  7310172001   AFDTV642ZGJ8S
# 2   171125  7310172001  A32TR272T1PFE1
# 3   171126  7310172001  A3JDAZ5YVHY15U
# 4   171127  7310172001   AS8WFSJTEPKX0
# 5   171128  7310172001  A371B3Z09W4GT5
# 6   171129  7310172001  A21N1PT1A908KW
# 7   171130  7310172001  A29JUMRL1US6YP
# 8   171131  7310172001  A24CFW43ZERCSU
# 9   171132  7310172001  A296N1BPL2LBAA
# 10  171133  7310172001  A3CEN1KNU51AD0
# 11  171134  7310172001  A3G8C334EDZPP7
# 12  171135  7310172001   AQHATKEPH80P0
# 13  171136  7310172001  A1WKFVJCSW1OW6
# 14  171137  7310172001  A38H80FBUIF8I3
# 15  171138  7310172001  A13LAE0YTXA11B
# 16  171139  7310172001  A13MS1JQG2ADOJ
# 17  171140  7310172001   ADXXVGRCGQQUO
# 18  171141  7310172001   AZ40270J4JBZN
# 19  171142  7310172001  A2ZO1AYFVQYG44
#
#                                          ProfileName  HelpfulnessNumerator  \
# ...

# %%
pd.read_sql_query("""select ProductId,UserId,ProfileName  FROM Reviews ORDER BY ProfileName DESC LIMIT 20 OFFSET 500""",amazon)
# Out:
#      ProductId          UserId ProfileName
# 0   B0053B7TUU  A3SIXO7D5FFA5F   zebramama
# 1   B000FV8LPU  A3SIXO7D5FFA5F   zebramama
# 2   B008JKTH2A  A3SIXO7D5FFA5F   zebramama
# 3   B001D0DMMY  A3SIXO7D5FFA5F   zebramama
# 4   B001D0DMME  A3SIXO7D5FFA5F   zebramama
# 5   B001D09KAM  A3SIXO7D5FFA5F   zebramama
# 6   B002AUF10M  A3SIXO7D5FFA5F   zebramama
# 7   B008JKSJJ2  A3SIXO7D5FFA5F   zebramama
# 8   B008JKU2CO  A3SIXO7D5FFA5F   zebramama
# 9   B004J0MX2U  A145LR47TVMPOA  zebralover
# 10  B0018CLW74  A353UEXE7VUBCK      zeboho
# 11  B000ELGPAO   A66X34TUYLC5J  zeb wilder
# 12  B002JANPDI   ATDL0WGO90USP       zdubs
# 13  B007JFMH8M  A2ICI5CWUSBMSS    zdrobles
# 14  B001PQTYN2  A2Y3VYHJQ6TZ64    zcstik28
# 15  B001B13TUU  A1BOW6Y2ZG8Q9Z      zckbrn
# 16  B00472ESQY  A1BOW6Y2ZG8Q9Z      zckbrn
# 17  B0019GVBTS  A2V2AK3OXYCN19   zchef0209
# 18  B006PHFBYW   AAELI4UD39C3F       zcats
# 19  B000ES972U  A1NX7AD2MIC8Z2          zc

# %%
pd.read_sql_query("""SELECT ProductId FROM Reviews GROUP BY ProductId LIMIT 20""",amazon)
# Out:
#      ProductId
# 0   0006641040
# 1   141278509X
# 2   2734888454
# 3   2841233731
# 4   7310172001
# 5   7310172101
# 6   7800648702
# 7   9376674501
# 8   B00002N8SM
# 9   B00002NCJC
# 10  B00002Z754
# 11  B00004CI84
# 12  B00004CXX9
# 13  B00004RAMS
# 14  B00004RAMV
# 15  B00004RAMX
# 16  B00004RAMY
# 17  B00004RBDU
# 18  B00004RBDW
# 19  B00004RBDZ

# %%
pd.read_sql_query("""SELECT DISTINCT ProductId, UserID FROM Reviews GROUP BY ProductId LIMIT 20""",amazon)
# Out:
#      ProductId          UserId
# 0   0006641040   A25ACLV5KPB4W
# 1   141278509X   AB1A5EGHHVA9M
# 2   2734888454  A1C298ITT645B6
# 3   2841233731  A3QD68O22M2XHQ
# 4   7310172001   ADODIH2V6UBQ9
# 5   7310172101   ADODIH2V6UBQ9
# 6   7800648702  A32EOHLFZYXJEP
# 7   9376674501   AJ1ETJII360FG
# 8   B00002N8SM  A110QUC2ULFN7R
# 9   B00002NCJC  A13RRPGE79XFFH
# 10  B00002Z754  A29Z5PI9BW2PU3
# 11  B00004CI84  A3KV0NO0TQTW3Y
# 12  B00004CXX9  A3KV0NO0TQTW3Y
# 13  B00004RAMS  A36DP42G19ZICT
# 14  B00004RAMV  A1RVL257CTT821
# 15  B00004RAMX  A3IHEDW36O48FF
# 16  B00004RAMY  A1LW5RIRK9YFCN
# 17  B00004RBDU   AI2HKXZRY0WVH
# 18  B00004RBDW  A3ASSGV7MH0NF7
# 19  B00004RBDZ  A1WQU4PV9AD6AU

# %%
pd.read_sql_query("""SELECT DISTINCT ProductId FROM Reviews GROUP BY ProductId LIMIT 20""",amazon)
# Out:
#                 UserId   ProductId
# 0   #oc-R103C0QSV1DF5E  B006Q820X0
# 1   #oc-R109MU5OBBZ59U  B008I1XPKA
# 2   #oc-R10LFEMQEW6QGZ  B008I1XPKA
# 3   #oc-R10LT57ZGIB140  B0026LJ3EA
# 4   #oc-R10UA029WVWIUI  B006Q820X0
# 5   #oc-R115TNMSPFT9I7  B007Y59HVM
# 6   #oc-R119LM8D59ZW8Y  B005DVVB9K
# 7   #oc-R11D9D7SHXIJB9  B005HG9ET0
# 8   #oc-R11D9LKDAN5NQJ  B008I1XPKA
# 9   #oc-R11DNU2NBKQ23Z  B007Y59HVM
# 10  #oc-R11O5J5ZVQE25C  B005HG9ET0
# 11  #oc-R11PW3CFBB4BEP  B006Q820X0
# 12  #oc-R11T1PHWNO7KEZ  B006Q820X0
# 13  #oc-R120LO6OLNDPCG  B006Q820X0
# 14  #oc-R12KPBODL2B5ZD  B007OSBE1U
# 15  #oc-R12MGTQS5KZZRV  B005HG9ET0
# 16  #oc-R12N3533IO3B79  B008I1XPKA
# 17  #oc-R13EBF129DBX88  B007Y59HVM
# 18  #oc-R13NNUL4EKL4FL  B005HG9ET0
# 19  #oc-R13X3YIJ6GLT0C  B005DVVB9K
# 20  #oc-R1493EDK6REQ02  B008I1XPKA
# 21  #oc-R149FDXLRARCWJ  B008I1XPKA
# 22  #oc-R14VLCY75KIBSB  B006Q820X0
# 23  #oc-R14ZSRYW2YB41B  B005HG9ET0
# 24  #oc-R14ZUK54VMOGJS  B006Q820X0
# 25  #oc-R1522DF2LUL4G1  B007TGDXMU
# ...

# %%
pd.read_sql_query("""SELECT * FROM Reviews WHERE Score!=3 LIMIT 20""",amazon)
# Out:
#     Id   ProductId          UserId                      ProfileName  \
# 0    1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1    2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2    3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3    4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4    5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5    6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6    7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7    8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8    9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9   10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
# 10  11  B0001PB9FE  A3HDKO7OW0QNK4                     Canadian Fan
# 11  12  B0009XLVG0  A2725IB4YY9JEB           A Poeng "SparkyGoHome"
# 12  13  B0009XLVG0   A327PCT23YH90                               LT
# ...

# %%
pd.read_sql_query("""SELECT * FROM Reviews WHERE Score=3 LIMIT 20""",amazon)
# Out:
#      Id   ProductId          UserId                   ProfileName  \
# 0    46  B001EO5QW8  A39Z97950MCTQE                   K. A. Freel
# 1    48  B001EO5QW8  A26AY1TFK8BQXQ             kbogo "shoelover"
# 2    50  B001EO5QW8  A276999Y6VRSCQ                          JMay
# 3    54  B000G6RPMY   AQ9DWWYP2KJCQ       Roel Trevino "protomex"
# 4    61  B004N5KULM  A1ZR8O62VSU4OK        Lisa J. Szlosek "lisa"
# 5    69  B000E7VI7S  A1KL2LAW08X6UQ                    calmnsense
# 6    79  B004X2KR36  A2AB7M9UCNBVN7                      sharonh4
# 7    84  B0019CW0HE  A1FD9E5C06UB6B                 BRENDA DEMERS
# 8    85  B0019CW0HE   AK2CXHH9VRZ2A                      I. GLENN
# 9   107  B004K2IHUO  A1ZKFQLHFZAEH9  S. J. Monson "world citizen"
# 10  130  B003OB0IB8  A28D854VMOEHGX                         Benny
# 11  145  B001GVISJW  A281387UUS2IN5                  Beantown Jim
# 12  149  B0064KU9HO   AJFIH0DZYJF7T                   Lisa Barton
# ...

# %%
pd.read_sql_query("""SELECT * FROM Reviews WHERE Score!=3 and Score!=4 and Id>30 LIMIT 20""",amazon)
# Out:
#     Id   ProductId          UserId                     ProfileName  \
# 0   31  B003F6UO7K   AFM0O9480F04W                         Sherril
# 1   32  B003F6UO7K  A31OQO709M20Y7         Molly V. Smith "staral"
# 2   35  B001EO5QW8  A2EB6OGOWCRU5H                      CorbyJames
# 3   37  B001EO5QW8  A1MYS9LFFBIYKM        Abby Chase "gluten free"
# 4   38  B001EO5QW8  A3MGP2E1ZZ6GRB            Zardoz "focuspuller"
# 5   40  B001EO5QW8   AO80AC8313NIZ                       kYpondman
# 6   41  B001EO5QW8   AQCY5KRO7489S                         Garrett
# 7   42  B001EO5QW8  A1WK4ALVZDYPUE        Dick Baldwin "christobe"
# 8   43  B001EO5QW8  A16XFOYQSJREL7                  Roger Pugliese
# 9   44  B001EO5QW8  A17DW6SUOC70DJ                     Mother of 9
# 10  45  B001EO5QW8  A2G7B7FKP2O2PU                      D. Leschke
# 11  47  B001EO5QW8   AQLL2R1PPR46X                   grumpyrainbow
# 12  51  B001EO5QW8  A108P30XVUFKXY                       Roberto A
# ...

# %%
pd.read_sql_query("""SELECT * FROM Reviews WHERE Score=3 or Score=4  LIMIT 5""",amazon)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 1   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 2  14  B001GVISJM  A18ECVX2RJ7HUE                  willie "roadie"
# 3  28  B001GVISJM   AAAS38B98HMIK                     Heather Dube
# 4  33  B001EO5QW8   AOVROBZ8BNTP7                        S. Potter
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      4  1219017600
# 1                     0                       0      4  1342051200
# 2                     2                       2      4  1288915200
# 3                     0                       1      4  1331856000
# 4                    19                      19      4  1163376000
#
#                         Summary  \
# 0         "Delight" says it all
# 1                    Nice Taffy
# 2             fresh and greasy!
# ...

# %%
pd.read_sql_query("""SELECT * FROM Reviews WHERE ID BETWEEN 500 AND 505  """,amazon)
# Out:
#     Id   ProductId          UserId     ProfileName  HelpfulnessNumerator  \
# 0  500  B000G6RYNE   A83YQC1XOU4CS        J. Baker                     0
# 1  501  B000G6RYNE  A2LGWBIT9WCTVA     D. Gesswein                     0
# 2  502  B000G6RYNE  A3TX8RH943OLBM           annie                     3
# 3  503  B000G6RYNE  A3L4OZ0U0A5UDH  Linda Mullings                     1
# 4  504  B000G6RYNE  A2OEUROGZDTXUJ       J. Graves                     1
# 5  505  B000G6RYNE  A30H2335OM7RD6   apoem "apoem"                     1
#
#    HelpfulnessDenominator  Score        Time                 Summary  \
# 0                       0      5  1183420800       The best I've had
# 1                       0      5  1173312000         Excellent chip!
# 2                       5      2  1214006400  salt and vinegar chips
# 3                       2      5  1349136000             Delicious!!
# 4                       2      4  1327968000            I like them.
# ...

# %%
pd.read_sql_query("""SELECT DISTINCT * FROM Reviews WHERE ID BETWEEN 500 AND 600 """,amazon)
# Out:
#       Id   ProductId          UserId  \
# 0    500  B000G6RYNE   A83YQC1XOU4CS
# 1    501  B000G6RYNE  A2LGWBIT9WCTVA
# 2    502  B000G6RYNE  A3TX8RH943OLBM
# 3    503  B000G6RYNE  A3L4OZ0U0A5UDH
# 4    504  B000G6RYNE  A2OEUROGZDTXUJ
# 5    505  B000G6RYNE  A30H2335OM7RD6
# 6    506  B000G6RYNE  A2SYKMR242D0X6
# 7    507  B000G6RYNE  A27YPCR3ZXWVFE
# 8    508  B000G6RYNE  A39Y59C6FTC0GL
# 9    509  B000G6RYNE  A3I5AT1101AS3A
# 10   510  B000G6RYNE  A22LENLDTGQIU7
# 11   511  B000G6RYNE  A2ZCD6KO2YY9IZ
# 12   512  B000G6RYNE  A2C18CH1YC6BYT
# 13   513  B000G6RYNE  A2M8JQ3AME7878
# 14   514  B000G6RYNE  A3B6TOEXSQVO24
# 15   515  B000G6RYNE  A16S0NQ3MWJXFL
# 16   516  B000G6RYNE  A1UM73T71CFPSY
# 17   517  B000G6RYNE  A38KP1POQ191WT
# 18   518  B000G6RYNE  A1AVLKAXW55QQA
# 19   519  B000G6RYNE  A2DQBXU2LEVWWA
# 20   520  B000G6RYNE   A4NDPXCYKRCY2
# 21   521  B000G6RYNE  A3TK2IOP8UQ087
# 22   522  B000G6RYNE   AYBYYDVV5ABJE
# 23   523  B000G6RYNE  A3MFU0GVZUVH3K
# ...

# %%
pd.read_sql_query("""SELECT DISTINCT * FROM Reviews WHERE ProductId IN ('B000G6RYNE','C001EO5QW8')  LIMIT 100""",amazon)
# Out:
#      Id   ProductId          UserId                     ProfileName  \
# 0   423  B000G6RYNE  A2NO1TXXS9T0EE                    BruteNStones
# 1   424  B000G6RYNE  A1IRN1M05TPOVT    Sharon M. Helfand "Scrapper"
# 2   425  B000G6RYNE   ARONI7W0W677H                         Peter N
# 3   426  B000G6RYNE  A1Y3XPZK9ZADFW                      albinocrow
# 4   427  B000G6RYNE  A1Y3XPZK9ZADFW                      albinocrow
# 5   428  B000G6RYNE  A1ELZC3WXWILX2                       B. Carter
# 6   429  B000G6RYNE  A1X5RAIMX4ZSLJ                       BadPotato
# 7   430  B000G6RYNE  A1IRN1M05TPOVT    Sharon M. Helfand "Scrapper"
# 8   431  B000G6RYNE  A1S8ELUE383P8E    John F. Peters "John Peters"
# 9   432  B000G6RYNE  A2OEUROGZDTXUJ                       J. Graves
# 10  433  B000G6RYNE  A17V3UVYMI69TE                    Patrick Tran
# 11  434  B000G6RYNE   A22PUBSSNP54L        G. Little "value seeker"
# 12  435  B000G6RYNE  A15USNEAJUXOSH                      L. Schrank
# ...

# %%
pd.read_sql_query("""SELECT MIN(Score) FROM Reviews LIMIT 100""",amazon)
# Out:
#    MIN(Score)
# 0           1

# %%
pd.read_sql_query("""SELECT MAX(Score) FROM Reviews LIMIT 100""",amazon)
# Out:
#    MAX(Score)
# 0           5

# %%
pd.read_sql_query("""SELECT MAX(Score) FROM Reviews WHERE ProductId='B000G6RYNE' LIMIT 100""",amazon)
# Out:
#    MAX(Score)
# 0           5

# %%
pd.read_sql_query("""SELECT MIN(Score) FROM Reviews WHERE ProductId='B000G6RYNE' LIMIT 100""",amazon)
# Out:
#    MIN(Score)
# 0           1

# %%
pd.read_sql_query("""SELECT SUM(Score) FROM Reviews WHERE ProductId='B000G6RYNE' LIMIT 100""",amazon)
# Out:
#    SUM(Score)
# 0         871

# %%
pd.read_sql_query("""SELECT COUNT(Score) FROM Reviews WHERE ProductId='B000G6RYNE' LIMIT 100""",amazon)
# Out:
#    COUNT(Score)
# 0           217

# %%
pd.read_sql_query("""SELECT AVG(Score) FROM Reviews WHERE ProductId='B000G6RYNE' LIMIT 100""",amazon)
# Out:
#    AVG(Score)
# 0    4.013825

# %%
871/217
# Out:
# 4

# %%
pd.read_sql_query("""SELECT COUNT(Score) FROM Reviews WHERE ProductId='B000G6RYNE' AND Score > 3""",amazon)
# Out:
#    COUNT(Score)
# 0           161

# %%
pd.read_sql_query("""SELECT COUNT(Score) FROM Reviews WHERE ProductId='B000G6RYNE' AND Score <= 3""",amazon)
# Out:
#    COUNT(Score)
# 0            56

# %%
pd.read_sql_query("""SELECT COUNT(Score) FROM Reviews WHERE ProductId='B000G6RYNE'""",amazon)
# Out:
#    COUNT(Score)
# 0           217
